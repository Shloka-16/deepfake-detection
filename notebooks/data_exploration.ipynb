# %%
from datasets import load_dataset

dataset = load_dataset("kristinealli/ffhq-dataset")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/1.30k [00:00<?, ?B/s]
# Resolving data files:   0%|          | 0/70000 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/70000 [00:03<?, ?files/s]
# Part1/00002.png:   0%|          | 0.00/984k [00:00<?, ?B/s]
# Part1/00004.png:   0%|          | 0.00/1.45M [00:00<?, ?B/s]
# Part1/00005.png:   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# Part1/00000.png:   0%|          | 0.00/1.49M [00:00<?, ?B/s]
# Part1/00003.png:   0%|          | 0.00/1.46M [00:00<?, ?B/s]
# Part1/00006.png:   0%|          | 0.00/1.40M [00:00<?, ?B/s]
# Part1/00008.png:   0%|          | 0.00/1.30M [00:00<?, ?B/s]
# Part1/00010.png:   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Part1/00011.png:   0%|          | 0.00/1.24M [00:00<?, ?B/s]
# Part1/00001.png:   0%|          | 0.00/1.28M [00:00<?, ?B/s]
# Part1/00007.png:   0%|          | 0.00/1.25M [00:00<?, ?B/s]
# Part1/00009.png:   0%|          | 0.00/940k [00:00<?, ?B/s]
# Part1/00013.png:   0%|          | 0.00/1.30M [00:00<?, ?B/s]
# Part1/00014.png:   0%|          | 0.00/1.47M [00:00<?, ?B/s]
# Part1/00015.png:   0%|          | 0.00/1.50M [00:00<?, ?B/s]
# Part1/00012.png:   0%|          | 0.00/1.14M [00:00<?, ?B/s]
# Part1/00016.png:   0%|          | 0.00/1.46M [00:00<?, ?B/s]
# Part1/00017.png:   0%|          | 0.00/966k [00:00<?, ?B/s]
# Part1/00018.png:   0%|          | 0.00/1.40M [00:00<?, ?B/s]
# Part1/00019.png:   0%|          | 0.00/1.27M [00:00<?, ?B/s]
# Part1/00020.png:   0%|          | 0.00/1.38M [00:00<?, ?B/s]
# Part1/00022.png:   0%|          | 0.00/1.48M [00:00<?, ?B/s]
# Part1/00021.png:   0%|          | 0.00/1.37M [00:00<?, ?B/s]
# Part1/00024.png:   0%|          | 0.00/1.54M [00:00<?, ?B/s]
# Part1/00023.png:   0%|          | 0.00/1.44M [00:00<?, ?B/s]
# Part1/00025.png:   0%|          | 0.00/1.51M [00:00<?, ?B/s]
# Part1/00026.png:   0%|          | 0.00/1.58M [00:00<?, ?B/s]
# Part1/00027.png:   0%|          | 0.00/1.22M [00:00<?, ?B/s]
# Part1/00028.png:   0%|          | 0.00/1.38M [00:00<?, ?B/s]
# Part1/00029.png:   0%|          | 0.00/1.17M [00:00<?, ?B/s]
# Part1/00031.png:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# Part1/00032.png:   0%|          | 0.00/1.41M [00:00<?, ?B/s]
# Part1/00030.png:   0%|          | 0.00/1.28M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 3
#       1 from datasets import load_dataset
#       2
# ----> 3 dataset = load_dataset("kristinealli/ffhq-dataset")
#
# File ~/VS Code/deepfake-detection/.venv/lib/python3.14/site-packages/datasets/load.py:1718, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1715     return builder_instance.as_streaming_dataset(split=split)
#    1717 # Download and prepare data
# -> 1718 builder_instance.download_and_prepare(
#    1719     download_config=download_config,
#    1720     download_mode=download_mode,
#    1721     verification_mode=verification_mode,
#    1722     num_proc=num_proc,
#    1723     storage_options=storage_options,
#    1724 )
#    1726 # Build dataset for splits
#    1727 keep_in_memory = (
#    1728     keep_in_memory if keep_in_memory is not None else is_small_dataset(builder_instance.info.dataset_size)
#    1729 )
#
# File ~/VS Code/deepfake-detection/.venv/lib/python3.14/site-packages/datasets/builder.py:890, in DatasetBuilder.download_and_prepare(self, output_dir, download_config, download_mode, verification_mode, dl_manager, base_path, file_format, max_shard_size, num_proc, storage_options, **download_and_prepare_kwargs)
#     888 if num_proc is not None:
#     889     prepare_split_kwargs["num_proc"] = num_proc
# --> 890 self._download_and_prepare(
#     891     dl_manager=dl_manager,
#     892     verification_mode=verification_mode,
#     893     **prepare_split_kwargs,
#     894     **download_and_prepare_kwargs,
#     895 )
#     896 # Sync info
#     897 self.info.dataset_size = sum(split.num_bytes for split in self.info.splits.values())
#
# File ~/VS Code/deepfake-detection/.venv/lib/python3.14/site-packages/datasets/builder.py:1577, in GeneratorBasedBuilder._download_and_prepare(self, dl_manager, verification_mode, **prepare_splits_kwargs)
#    1576 def _download_and_prepare(self, dl_manager, verification_mode, **prepare_splits_kwargs):
# -> 1577     super()._download_and_prepare(
#    1578         dl_manager,
#    1579         verification_mode,
#    1580         **prepare_splits_kwargs,
#    1581     )
#
# File ~/VS Code/deepfake-detection/.venv/lib/python3.14/site-packages/datasets/builder.py:929, in DatasetBuilder._download_and_prepare(self, dl_manager, verification_mode, **prepare_split_kwargs)
#     927 split_dict = SplitDict(dataset_name=self.dataset_name)
#     928 split_generators_kwargs = self._make_split_generators_kwargs(prepare_split_kwargs)
# --> 929 split_generators: list[SplitGenerator] = self._split_generators(dl_manager, **split_generators_kwargs)
#     931 # Checksums verification
#     932 if verification_mode == VerificationMode.ALL_CHECKS and dl_manager.record_checksums:
#
# File ~/VS Code/deepfake-detection/.venv/lib/python3.14/site-packages/datasets/packaged_modules/folder_based_builder/folder_based_builder.py:127, in FolderBasedBuilder._split_generators(self, dl_manager)
#     125 for split_name, files in data_files.items():
#     126     files, metadata_files, archives = self._split_files_and_metadata_and_archives(files)
# --> 127     downloaded_files = dl_manager.download(files)
#     128     downloaded_metadata_files = dl_manager.download(metadata_files)
#     129     downloaded_dirs = dl_manager.download_and_extract(archives)
#
# File ~/VS Code/deepfake-detection/.venv/lib/python3.14/site-packages/datasets/download/download_manager.py:159, in DownloadManager.download(self, url_or_urls)
#     157 start_time = datetime.now()
#     158 with stack_multiprocessing_download_progress_bars():
# --> 159     downloaded_path_or_paths = map_nested(
#     160         download_func,
#     161         url_or_urls,
#     162         map_tuple=True,
#     163         num_proc=download_config.num_proc,
#     164         desc="Downloading data files",
#     165         batched=True,
#     166         batch_size=-1,
#     167     )
#     168 duration = datetime.now() - start_time
#     169 logger.info(f"Downloading took {duration.total_seconds() // 60} min")
#
# File ~/VS Code/deepfake-detection/.venv/lib/python3.14/site-packages/datasets/utils/py_utils.py:520, in map_nested(function, data_struct, dict_only, map_list, map_tuple, map_numpy, num_proc, parallel_min_length, batched, batch_size, types, disable_tqdm, desc)
#     517         batch_size = max(len(iterable) // num_proc + int(len(iterable) % num_proc > 0), 1)
#     518     iterable = list(iter_batched(iterable, batch_size))
#     519 mapped = [
# --> 520     _single_map_nested((function, obj, batched, batch_size, types, None, True, None))
#     521     for obj in hf_tqdm(iterable, disable=disable_tqdm, desc=desc)
#     522 ]
#     523 if batched:
#     524     mapped = [mapped_item for mapped_batch in mapped for mapped_item in mapped_batch]
#
# File ~/VS Code/deepfake-detection/.venv/lib/python3.14/site-packages/datasets/utils/py_utils.py:388, in _single_map_nested(args)
#     381         return function(data_struct)
#     382 if (
#     383     batched
#     384     and not isinstance(data_struct, dict)
#     385     and isinstance(data_struct, types)
#     386     and all(not isinstance(v, (dict, types)) for v in data_struct)
#     387 ):
# --> 388     return [mapped_item for batch in iter_batched(data_struct, batch_size) for mapped_item in function(batch)]
#     390 # Reduce logging to keep things readable in multiprocessing with tqdm
#     391 if rank is not None and logging.get_verbosity() < logging.WARNING:
#
# File ~/VS Code/deepfake-detection/.venv/lib/python3.14/site-packages/datasets/download/download_manager.py:206, in DownloadManager._download_batched(self, url_or_filenames, download_config)
#     201         pass
#     202     max_workers = (
#     203         config.HF_DATASETS_MULTITHREADING_MAX_WORKERS if size < (20 << 20) else 1
#     204     )  # enable multithreading if files are small
# --> 206     return thread_map(
#     207         download_func,
#     208         url_or_filenames,
#     209         desc=download_config.download_desc or "Downloading",
#     210         unit="files",
#     211         position=multiprocessing.current_process()._identity[-1]  # contains the ranks of subprocesses
#     212         if os.environ.get("HF_DATASETS_STACK_MULTIPROCESSING_DOWNLOAD_PROGRESS_BARS") == "1"
#     213         and multiprocessing.current_process()._identity
#     214         else None,
#     215         max_workers=max_workers,
#     216         tqdm_class=tqdm,
#     217     )
#     218 else:
#     219     return [
#     220         self._download_single(url_or_filename, download_config=download_config)
#     221         for url_or_filename in url_or_filenames
#     222     ]
#
# File ~/VS Code/deepfake-detection/.venv/lib/python3.14/site-packages/tqdm/contrib/concurrent.py:69, in thread_map(fn, *iterables, **tqdm_kwargs)
#      55 """
#      56 Equivalent of `list(map(fn, *iterables))`
#      57 driven by `concurrent.futures.ThreadPoolExecutor`.
#    (...)     66     [default: max(32, cpu_count() + 4)].
#      67 """
#      68 from concurrent.futures import ThreadPoolExecutor
# ---> 69 return _executor_map(ThreadPoolExecutor, fn, *iterables, **tqdm_kwargs)
#
# File ~/VS Code/deepfake-detection/.venv/lib/python3.14/site-packages/tqdm/contrib/concurrent.py:51, in _executor_map(PoolExecutor, fn, *iterables, **tqdm_kwargs)
#      47 with ensure_lock(tqdm_class, lock_name=lock_name) as lk:
#      48     # share lock in case workers are already using `tqdm`
#      49     with PoolExecutor(max_workers=max_workers, initializer=tqdm_class.set_lock,
#      50                       initargs=(lk,)) as ex:
# ---> 51         return list(tqdm_class(ex.map(fn, *iterables, chunksize=chunksize), **kwargs))
#
# File ~/VS Code/deepfake-detection/.venv/lib/python3.14/site-packages/tqdm/notebook.py:252, in tqdm_notebook.__iter__(self)
#     250 try:
#     251     it = super().__iter__()
# --> 252     yield from it
#     253 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#     254 except:  # NOQA
#
# File ~/VS Code/deepfake-detection/.venv/lib/python3.14/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progress bar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/_base.py:639, in Executor.map.<locals>.result_iterator()
#     637 # Careful not to keep a reference to the popped future
#     638 if timeout is None:
# --> 639     yield _result_or_cancel(fs.pop())
#     640 else:
#     641     yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/_base.py:311, in _result_or_cancel(***failed resolving arguments***)
#     309 try:
#     310     try:
# --> 311         return fut.result(timeout)
#     312     finally:
#     313         fut.cancel()
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/_base.py:443, in Future.result(self, timeout)
#     441     raise CancelledError()
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#     447 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/_base.py:395, in Future.__get_result(self)
#     393 if self._exception is not None:
#     394     try:
# --> 395         raise self._exception
#     396     finally:
#     397         # Break a reference cycle with the exception in self._exception
#     398         self = None
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/thread.py:86, in _WorkItem.run(self, ctx)
#      83     return
#      85 try:
# ---> 86     result = ctx.run(self.task)
#      87 except BaseException as exc:
#      88     self.future.set_exception(exc)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/thread.py:73, in WorkerContext.run(self, task)
#      71 def run(self, task):
#      72     fn, args, kwargs = task
# ---> 73     return fn(*args, **kwargs)
#
# File ~/VS Code/deepfake-detection/.venv/lib/python3.14/site-packages/datasets/download/download_manager.py:229, in DownloadManager._download_single(self, url_or_filename, download_config)
#     226 if is_relative_path(url_or_filename):
#     227     # append the relative path to the base_path
#     228     url_or_filename = url_or_path_join(self._base_path, url_or_filename)
# --> 229 out = cached_path(url_or_filename, download_config=download_config)
#     230 out = tracked_str(out)
#     231 out.set_origin(url_or_filename)
#
# File ~/VS Code/deepfake-detection/.venv/lib/python3.14/site-packages/datasets/utils/file_utils.py:188, in cached_path(url_or_filename, download_config, **download_kwargs)
#     178 resolved_path = huggingface_hub.HfFileSystem(
#     179     endpoint=config.HF_ENDPOINT, token=download_config.token
#     180 ).resolve_path(url_or_filename)
#     181 try:
#     182     output_path = huggingface_hub.HfApi(
#     183         endpoint=config.HF_ENDPOINT,
#     184         token=download_config.token,
#     185         library_name="datasets",
#     186         library_version=__version__,
#     187         user_agent=get_datasets_user_agent(download_config.user_agent),
# --> 188     ).hf_hub_download(
#     189         repo_id=resolved_path.repo_id,
#     190         repo_type=resolved_path.repo_type,
#     191         revision=resolved_path.revision,
#     192         filename=resolved_path.path_in_repo,
#     193         force_download=download_config.force_download,
#     194         proxies=download_config.proxies,
#     195     )
#     196 except (
#     197     huggingface_hub.utils.RepositoryNotFoundError,
#     198     huggingface_hub.utils.EntryNotFoundError,
#     199     huggingface_hub.utils.RevisionNotFoundError,
#     200     huggingface_hub.utils.GatedRepoError,
#     201 ) as e:
#     202     raise FileNotFoundError(str(e)) from e
#
# File ~/VS Code/deepfake-detection/.venv/lib/python3.14/site-packages/huggingface_hub/utils/_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File ~/VS Code/deepfake-detection/.venv/lib/python3.14/site-packages/huggingface_hub/hf_api.py:6413, in HfApi.hf_hub_download(self, repo_id, filename, subfolder, repo_type, revision, cache_dir, local_dir, force_download, etag_timeout, token, local_files_only, tqdm_class, dry_run)
#    6409         if token is None:
#    6410             # Cannot do `token = token or self.token` as token can be `False`.
#    6411             token = self.token
#    6412
# -> 6413         return hf_hub_download(
#    6414             repo_id=repo_id,
#    6415             filename=filename,
#    6416             subfolder=subfolder,
#
# File ~/VS Code/deepfake-detection/.venv/lib/python3.14/site-packages/huggingface_hub/utils/_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File ~/VS Code/deepfake-detection/.venv/lib/python3.14/site-packages/huggingface_hub/file_download.py:1016, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#     995     return _hf_hub_download_to_local_dir(
#     996         # Destination
#     997         local_dir=local_dir,
#    (...)   1013         dry_run=dry_run,
#    1014     )
#    1015 else:
# -> 1016     return _hf_hub_download_to_cache_dir(
#    1017         # Destination
#    1018         cache_dir=cache_dir,
#    1019         # File info
#    1020         repo_id=repo_id,
#    1021         filename=filename,
#    1022         repo_type=repo_type,
#    1023         revision=revision,
#    1024         # HTTP info
#    1025         endpoint=endpoint,
#    1026         etag_timeout=etag_timeout,
#    1027         headers=hf_headers,
#    1028         token=token,
#    1029         # Additional options
#    1030         local_files_only=local_files_only,
#    1031         force_download=force_download,
#    1032         tqdm_class=tqdm_class,
#    1033         dry_run=dry_run,
#    1034     )
#
# File ~/VS Code/deepfake-detection/.venv/lib/python3.14/site-packages/huggingface_hub/file_download.py:1238, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1235 # Local file doesn't exist or etag isn't a match => retrieve file from remote (or cache)
#    1237 with WeakFileLock(lock_path):
# -> 1238     _download_to_tmp_and_move(
#    1239         incomplete_path=Path(blob_path + ".incomplete"),
#    1240         destination_path=Path(blob_path),
#    1241         url_to_download=url_to_download,
#    1242         headers=headers,
#    1243         expected_size=expected_size,
#    1244         filename=filename,
#    1245         force_download=force_download,
#    1246         etag=etag,
#    1247         xet_file_data=xet_file_data,
#    1248         tqdm_class=tqdm_class,
#    1249     )
#    1250     if not os.path.exists(pointer_path):
#    1251         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File ~/VS Code/deepfake-detection/.venv/lib/python3.14/site-packages/huggingface_hub/file_download.py:1861, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, headers, expected_size, filename, force_download, etag, xet_file_data, tqdm_class)
#    1859 if xet_file_data is not None and is_xet_available():
#    1860     logger.debug("Xet Storage is enabled for this repo. Downloading file from Xet Storage..")
# -> 1861     xet_get(
#    1862         incomplete_path=tmp_path,
#    1863         xet_file_data=xet_file_data,
#    1864         headers=headers,
#    1865         expected_size=expected_size,
#    1866         displayed_filename=filename,
#    1867         tqdm_class=tqdm_class,
#    1868     )
#    1869 else:
#    1870     if xet_file_data is not None and not constants.HF_HUB_DISABLE_XET:
#
# File ~/VS Code/deepfake-detection/.venv/lib/python3.14/site-packages/huggingface_hub/file_download.py:566, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, tqdm_class, _tqdm_bar)
#     563     _prev = current
#     565 try:
# --> 566     with session.new_file_download_group(
#     567         token_refresh_url=xet_file_data.refresh_route,
#     568         token_refresh_headers=headers,
#     569         custom_headers=xet_headers,
#     570         progress_callback=_on_progress,
#     571     ) as group:
#     572         group.start_download_file(
#     573             XetFileInfo(xet_file_data.file_hash, expected_size), str(incomplete_path.absolute())
#     574         )
#     575 except KeyboardInterrupt:
#
# RuntimeError: Task error: File reconstruction error: CAS Client Error: Request error: HTTP status client error (404 Not Found), domain: https://cas-server.xethub.hf.co/v1/reconstructions/d8e6752f7bb9f3696f1b5e16d1aeb7b3bb1660dd0fbd19c7d3353e98a4b5d6ec

# %%
import random
import matplotlib.pyplot as plt

train_data = dataset["train"]

for i in range(6):

    idx = random.randint(0, len(train_data) - 1)
    sample = train_data[idx]

    plt.figure(figsize=(3,3))
    plt.imshow(sample["image"])
    plt.title("REAL (FFHQ)")
    plt.axis("off")
    plt.show()
